# %% [markdown]
# # Criando variaveis para quantitative finance models
#
# - O intuito deste código é mostrar algumas variáveis que podem ser usadas em modelos quantitativos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
import os 
os.getcwd()
# Out:
# '/home/marcos_well/Área de Trabalho/Projetos_Python/Python_para_investimentos/quant'

# %%
os.chdir('/home/marcos_well/Área de Trabalho/Projetos_Python/om/dados')

# %%
df = pd.read_csv('BTC-USD.csv')

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-12-09  361.894989  363.066986  344.950989  352.218994  352.218994
# 1  2014-12-10  352.204987  352.384003  346.364990  346.364990  346.364990
# 2  2014-12-11  344.339996  361.356995  338.763000  350.506012  350.506012
# 3  2014-12-12  350.833008  352.983002  349.290985  352.541992  352.541992
# 4  2014-12-13  352.381012  352.381012  346.588013  347.376007  347.376007
#
#        Volume
# 0  32915500.0
# 1  16427700.0
# 2  32431300.0
# 3  16989800.0
# 4  11675900.0

# %% [markdown]
# # Criação das Variaveis

# %%
# Retorno diario
df['Retorno_diario'] = df['Close'].pct_change(1)
df['Retorno_semanal'] = df['Close'].pct_change(7)

# desvio padrão std() - Volatilidade
df['std_5'] = df['Close'].rolling(5).std()
df['std_10'] = df['Close'].rolling(10).std()
df['Volatilidade'] = df['Close'].std()
# df['Volatilidade_anualizada'] = df['Volatilidade'] * (252 ** 0.5)  # 252 dias úteis em um ano

# media movel 
df['mm_5'] = df['Close'].rolling(5).mean()
df['mm_10'] = df['Close'].rolling(10).mean()

# proporção do corpo do candle em relação ao renge do dia
df['prop'] = (df['Close'] - df['Open'])/(df['High'] - df['Low'])

# direção do dia atual
df['dir_D'] = np.where(df['Close'] > df['Open'] , 1 , 0)

# Calcular o índice de força - FI
df['FI'] = (df['Close'] - df['Close'].shift(1)) * df['Volume']

# %%
# Razão entre os preços atuais e os preços anteriores
df['Momentum'] = df['Close'] / df['Close'].shift(1)  
df['Momentum_5'] = df['Close'] / df['Close'].shift(5) - 1  
df['Momentum_10'] = df['Close'] / df['Close'].shift(10) - 1  

# Variáveis de tendência
# Indicador de tendência ascendente em relação à média móvel 
df['Tendencia_5'] = np.where(df['Close'] > df['Close'].rolling(5).mean(), 1, 0)   
df['Tendencia_10'] = np.where(df['Close'] > df['Close'].rolling(10).mean(), 1, 0)  


# Variáveis de médias móveis exponenciais
df['EMA_5'] = df['Close'].ewm(span=5).mean()  
df['EMA_10'] = df['Close'].ewm(span=10).mean()

# %%
# limpando o DataFrame
df_filtrado = df.dropna(axis=0)

# %%
df_filtrado.tail()
# Out:
#             Date          Open          High           Low         Close  \
# 3106  2023-06-11  25854.031250  26203.439453  25668.986328  25940.167969
# 3107  2023-06-12  25934.285156  26087.919922  25675.197266  25902.500000
# 3108  2023-06-13  25902.941406  26376.351563  25728.365234  25918.728516
# 3109  2023-06-14  25920.257813  26041.800781  24902.152344  25124.675781
# 3110  2023-06-15  25121.673828  25735.308594  24797.167969  25576.394531
#
#          Adj Close        Volume  Retorno_diario  Retorno_semanal       std_5  \
# 3106  25940.167969  1.073261e+10        0.003440        -0.043471  308.583101
# 3107  25902.500000  1.167789e+10       -0.001452         0.005528  328.290570
# 3108  25918.728516  1.414347e+10        0.000627        -0.048462  260.216520
# 3109  25124.675781  1.426572e+10       -0.030636        -0.046357  349.691717
# 3110  25576.394531  1.583738e+10        0.017979        -0.035152  350.900124
#
#       ...      prop  dir_D            FI  Momentum  Momentum_5  Momentum_10  \
# 3106  ...  0.161168      1  9.544267e+11  1.003440   -0.047675    -0.032804
# 3107  ... -0.077013      0 -4.398824e+11  0.998548   -0.016834    -0.049435
# 3108  ...  0.024363      1  2.295276e+11  1.000627   -0.022238    -0.042711
# 3109  ... -0.698094      0 -1.132773e+13  0.969364   -0.051196    -0.073542
# 3110  ...  0.484704      1  7.154043e+12  1.017979   -0.010632    -0.007131
#
#       Tendencia_5  Tendencia_10         EMA_5        EMA_10
# 3106            0             0  26206.056740  26460.567022
# 3107            0             0  26104.871160  26359.100291
# 3108            0             0  26042.823612  26279.032695
# 3109            0             0  25736.774335  26069.149620
# 3110            0             0  25683.314400  25979.557786
#
# [5 rows x 24 columns]

# %% [markdown]
# # Corrrelação entre as Variaveis

# %%
df_filtrado.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Retorno_diario', 'Retorno_semanal', 'std_5', 'std_10', 'Volatilidade',
#        'mm_5', 'mm_10', 'prop', 'dir_D', 'FI', 'Momentum', 'Momentum_5',
#        'Momentum_10', 'Tendencia_5', 'Tendencia_10', 'EMA_5', 'EMA_10'],
#       dtype='object')

# %%
variaveis = df_filtrado.iloc[:, 7:df_filtrado.shape[1]]

# %%
# Heat Map 

variaveis_hm = variaveis.corr()

fig, ax = plt.subplots(figsize=(20,20))

sns.heatmap(variaveis_hm, cmap = 'coolwarm', annot = True, linewidths = 6, ax=ax);

# %%
variaveis_hm
# Out:
#                  Retorno_diario  Retorno_semanal     std_5    std_10  \
# Retorno_diario         1.000000         0.392131 -0.021982 -0.016620
# Retorno_semanal        0.392131         1.000000 -0.008756 -0.013245
# std_5                 -0.021982        -0.008756  1.000000  0.879577
# std_10                -0.016620        -0.013245  0.879577  1.000000
# Volatilidade                NaN              NaN       NaN       NaN
# mm_5                  -0.028699        -0.026491  0.791773  0.809048
# mm_10                 -0.032750        -0.055109  0.792381  0.810928
# prop                   0.788804         0.309610 -0.034520 -0.033700
# dir_D                  0.653925         0.235212 -0.032102 -0.028840
# FI                     0.511412         0.219254 -0.063507 -0.049399
# Momentum               1.000000         0.392131 -0.021982 -0.016620
# Momentum_5             0.446312         0.850543 -0.024408 -0.023425
# Momentum_10            0.312435         0.844205  0.004413  0.002805
# Tendencia_5            0.460034         0.496253 -0.045688 -0.037485
# Tendencia_10           0.349512         0.658436 -0.042847 -0.045218
# EMA_5                 -0.024450        -0.024958  0.791384  0.809313
# EMA_10                -0.030040        -0.045176  0.791772  0.810069
#
#                  Volatilidade      mm_5     mm_10      prop     dir_D  \
# Retorno_diario            NaN -0.028699 -0.032750  0.788804  0.653925
# Retorno_semanal           NaN -0.026491 -0.055109  0.309610  0.235212
# std_5                     NaN  0.791773  0.792381 -0.034520 -0.032102
# std_10                    NaN  0.809048  0.810928 -0.033700 -0.028840
# Volatilidade              NaN       NaN       NaN       NaN       NaN
# mm_5                      NaN  1.000000  0.998930 -0.051292 -0.052328
# mm_10                     NaN  0.998930  1.000000 -0.054149 -0.054205
# prop                      NaN -0.051292 -0.054149  1.000000  0.875992
# dir_D                     NaN -0.052328 -0.054205  0.875992  1.000000
# FI                        NaN -0.037259 -0.043728  0.358956  0.311504
# Momentum                  NaN -0.028699 -0.032750  0.788804  0.653925
# Momentum_5                NaN -0.032631 -0.056231  0.354229  0.274079
# Momentum_10               NaN -0.020134 -0.047764  0.258548  0.201802
# Tendencia_5               NaN -0.051755 -0.062031  0.535320  0.448381
# Tendencia_10              NaN -0.041378 -0.060019  0.388455  0.304439
# EMA_5                     NaN  0.999904  0.998952 -0.047975 -0.049615
# EMA_10                    NaN  0.999364  0.999805 -0.052248 -0.052619
#
#                        FI  Momentum  Momentum_5  Momentum_10  Tendencia_5  \
# Retorno_diario   0.511412  1.000000    0.446312     0.312435     0.460034
# Retorno_semanal  0.219254  0.392131    0.850543     0.844205     0.496253
# std_5           -0.063507 -0.021982   -0.024408     0.004413    -0.045688
# std_10          -0.049399 -0.016620   -0.023425     0.002805    -0.037485
# Volatilidade          NaN       NaN         NaN          NaN          NaN
# mm_5            -0.037259 -0.028699   -0.032631    -0.020134    -0.051755
# mm_10           -0.043728 -0.032750   -0.056231    -0.047764    -0.062031
# prop             0.358956  0.788804    0.354229     0.258548     0.535320
# dir_D            0.311504  0.653925    0.274079     0.201802     0.448381
# FI               1.000000  0.511412    0.249088     0.180359     0.235337
# Momentum         0.511412  1.000000    0.446312     0.312435     0.460034
# Momentum_5       0.249088  0.446312    1.000000     0.718933     0.583652
# Momentum_10      0.180359  0.312435    0.718933     1.000000     0.412993
# Tendencia_5      0.235337  0.460034    0.583652     0.412993     1.000000
# Tendencia_10     0.183269  0.349512    0.654520     0.598039     0.670340
# EMA_5           -0.031472 -0.024450   -0.028928    -0.019875    -0.046577
# EMA_10          -0.039483 -0.030040   -0.046600    -0.041479    -0.056651
#
#                  Tendencia_10     EMA_5    EMA_10
# Retorno_diario       0.349512 -0.024450 -0.030040
# Retorno_semanal      0.658436 -0.024958 -0.045176
# std_5               -0.042847  0.791384  0.791772
# std_10              -0.045218  0.809313  0.810069
# Volatilidade              NaN       NaN       NaN
# mm_5                -0.041378  0.999904  0.999364
# mm_10               -0.060019  0.998952  0.999805
# prop                 0.388455 -0.047975 -0.052248
# dir_D                0.304439 -0.049615 -0.052619
# FI                   0.183269 -0.031472 -0.039483
# Momentum             0.349512 -0.024450 -0.030040
# Momentum_5           0.654520 -0.028928 -0.046600
# Momentum_10          0.598039 -0.019875 -0.041479
# Tendencia_5          0.670340 -0.046577 -0.056651
# Tendencia_10         1.000000 -0.038624 -0.053016
# EMA_5               -0.038624  1.000000  0.999447
# EMA_10              -0.053016  0.999447  1.000000
